# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\91897\OneDrive\Desktop\datasets\Financials.csv")

# %%
df
# Out:
#               Segment                   Country     Product   Discount Band   \
# 0          Government                    Canada   Carretera            None
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...

# %% [markdown]
# ### **STEP 1 DATA UNDERSTANDING**
#
#
# *  **SHAPE**
# *  **HEAD AND TAIL**
# *  **DATA TYPES**
# *  **DESCRIBE(ALL DATA CHARACTERISTICS)**

# %%
df.shape
# Out:
# (700, 16)

# %%
df.head()
# Out:
#       Segment  Country     Product   Discount Band   Units Sold   \
# 0  Government   Canada   Carretera            None    $1,618.50
# 1  Government  Germany   Carretera            None    $1,321.00
# 2   Midmarket   France   Carretera            None    $2,178.00
# 3   Midmarket  Germany   Carretera            None      $888.00
# 4   Midmarket   Mexico   Carretera            None    $2,470.00
#
#    Manufacturing Price   Sale Price   Gross Sales   Discounts         Sales   \
# 0                $3.00       $20.00    $32,370.00        $-      $32,370.00
# 1                $3.00       $20.00    $26,420.00        $-      $26,420.00
# 2                $3.00       $15.00    $32,670.00        $-      $32,670.00
# 3                $3.00       $15.00    $13,320.00        $-      $13,320.00
# 4                $3.00       $15.00    $37,050.00        $-      $37,050.00
#
#           COGS        Profit         Date  Month Number  Month Name   Year
# ...

# %%
df.tail()
# Out:
#               Segment                   Country    Product   Discount Band   \
# 695    Small Business                    France   Amarilla            High
# 696    Small Business                    Mexico   Amarilla            High
# 697        Government                    Mexico    Montana            High
# 698        Government                    Canada      Paseo            High
# 699  Channel Partners  United States of America        VTT            High
#
#      Units Sold   Manufacturing Price   Sale Price     Gross Sales   \
# 695   $2,475.00               $260.00      $300.00    $7,42,500.00
# 696     $546.00               $260.00      $300.00    $1,63,800.00
# 697   $1,368.00                 $5.00        $7.00       $9,576.00
# 698     $723.00                $10.00        $7.00       $5,061.00
# 699   $1,806.00               $250.00       $12.00      $21,672.00
#
#          Discounts           Sales            COGS        Profit         Date  \
# ...

# %%
df.dtypes
# Out:
# Segment                  object
# Country                  object
#  Product                 object
#  Discount Band           object
#  Units Sold              object
#  Manufacturing Price     object
#  Sale Price              object
#  Gross Sales             object
#  Discounts               object
#   Sales                  object
#  COGS                    object
#  Profit                  object
# Date                     object
# Month Number              int64
#  Month Name              object
# Year                      int64
# dtype: object

# %%
df.describe()
# Out:
#        Month Number         Year
# count    700.000000   700.000000
# mean       7.900000  2013.750000
# std        3.377321     0.433322
# min        1.000000  2013.000000
# 25%        5.750000  2013.750000
# 50%        9.000000  2014.000000
# 75%       10.250000  2014.000000
# max       12.000000  2014.000000

# %% [markdown]
# ### **STEP 2 DATA PREPERATION**
#
# * **DROPING IRRELEVANT SPACES**
# *  **DROPPING IRRELEVANT ROWS AND COLUMNS**
# *  **IDENTIFYING DUPLICATE COLUMNS**
# *  **RENAMING COLUMNS**
# *  **FEATURE CREATION**
# *  **FILL WITH MEAN**

# %%
df.columns
# Out:
# Index(['Segment', 'Country', ' Product ', ' Discount Band ', ' Units Sold ',
#        ' Manufacturing Price ', ' Sale Price ', ' Gross Sales ', ' Discounts ',
#        '  Sales ', ' COGS ', ' Profit ', 'Date', 'Month Number',
#        ' Month Name ', 'Year'],
#       dtype='object')

# %%
df = df.rename(columns={col: col.strip() for col in df.columns})  #removing first and last columns

# %%
df.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount Band', 'Units Sold',
#        'Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts',
#        'Sales', 'COGS', 'Profit', 'Date', 'Month Number', 'Month Name',
#        'Year'],
#       dtype='object')

# %% [markdown]
# #### DROPING UNWANTED COLUMNS

# %%
df = df[['Segment', 'Country', 
#         'Product', 
#         'Discount Band', 
         'Units Sold', 
       'Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts',
       'Sales', 'COGS', 'Profit', 'Date']].copy()

# %%
df.head()
# Out:
#       Segment  Country   Units Sold Manufacturing Price Sale Price  \
# 0  Government   Canada   $1,618.50               $3.00     $20.00
# 1  Government  Germany   $1,321.00               $3.00     $20.00
# 2   Midmarket   France   $2,178.00               $3.00     $15.00
# 3   Midmarket  Germany     $888.00               $3.00     $15.00
# 4   Midmarket   Mexico   $2,470.00               $3.00     $15.00
#
#     Gross Sales Discounts         Sales          COGS        Profit  \
# 0   $32,370.00      $-      $32,370.00    $16,185.00    $16,185.00
# 1   $26,420.00      $-      $26,420.00    $13,210.00    $13,210.00
# 2   $32,670.00      $-      $32,670.00    $21,780.00    $10,890.00
# 3   $13,320.00      $-      $13,320.00     $8,880.00     $4,440.00
# 4   $37,050.00      $-      $37,050.00    $24,700.00    $12,350.00
#
#          Date
# 0  01-01-2014
# 1  01-01-2014
# 2  01-06-2014
# 3  01-06-2014
# 4  01-06-2014

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Segment              700 non-null    object
#  1   Country              700 non-null    object
#  2   Units Sold           700 non-null    object
#  3   Manufacturing Price  700 non-null    object
#  4   Sale Price           700 non-null    object
#  5   Gross Sales          700 non-null    object
#  6   Discounts            700 non-null    object
#  7   Sales                700 non-null    object
#  8   COGS                 700 non-null    object
#  9   Profit               700 non-null    object
#  10  Date                 700 non-null    object
# dtypes: object(11)
# memory usage: 60.3+ KB

# %% [markdown]
# #### IDENTIFYING ALL THE NULL VALUES IN DATA FRAME

# %%
df.isna().sum()
# Out:
# Segment                0
# Country                0
# Units Sold             0
# Manufacturing Price    0
# Sale Price             0
# Gross Sales            0
# Discounts              0
# Sales                  0
# COGS                   0
# Profit                 0
# Date                   0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 695    False
# 696    False
# 697    False
# 698    False
# 699    False
# Length: 700, dtype: bool

# %%
df.sample()
# Out:
#        Segment Country   Units Sold Manufacturing Price Sale Price  \
# 272  Midmarket  France   $3,801.00              $10.00     $15.00
#
#       Gross Sales    Discounts         Sales          COGS        Profit  \
# 272   $57,015.00    $3,420.90    $53,594.10    $38,010.00    $15,584.10
#
#            Date
# 272  01-04-2014

# %% [markdown]
# #### Drop  Dollar sign

# %%
df['Units Sold'] = df['Units Sold'].replace({'\$': '',',':'','\.': ''}, regex = True).astype(int)

df['Manufacturing Price'] = df['Manufacturing Price'].replace({'\$': '',',': '','\.': ''}, regex = True).astype(int)

df['Sale Price'] =df['Sale Price'].replace({'\$': '', ',':'', '\.':''}, regex = True).astype(int)

df['Gross Sales'] =df['Gross Sales'].replace({'\$': '', ',':'', '\.':''}, regex = True).astype(int)

df['Discounts'] = df['Discounts'].replace({'\$-': '0', '\$': '', ',': '', '\.': ''},regex = True).astype(int)

df['Sales'] =df['Sales'].replace({'\$': '', ',':'', '\.':''}, regex = True).astype(int)

df['COGS'] =df['COGS'].replace({'\$': '', ',':'', '\.':''}, regex = True).astype(int)

df['Profit'] = pd.to_numeric(df['Profit'].str.replace(r'[\$\,\.\-]', '', regex=True), errors='coerce')

df['Date'] =pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Segment                        object
# Country                        object
# Units Sold                      int32
# Manufacturing Price             int32
# Sale Price                      int32
# Gross Sales                     int32
# Discounts                       int32
# Sales                           int32
# COGS                            int32
# Profit                        float64
# Date                   datetime64[ns]
# dtype: object

# %%
df.head()
# Out:
#       Segment  Country  Units Sold  Manufacturing Price  Sale Price  \
# 0  Government   Canada      161850                  300        2000
# 1  Government  Germany      132100                  300        2000
# 2   Midmarket   France      217800                  300        1500
# 3   Midmarket  Germany       88800                  300        1500
# 4   Midmarket   Mexico      247000                  300        1500
#
#    Gross Sales  Discounts    Sales     COGS     Profit       Date
# 0      3237000          0  3237000  1618500  1618500.0 2014-01-01
# 1      2642000          0  2642000  1321000  1321000.0 2014-01-01
# 2      3267000          0  3267000  2178000  1089000.0 2014-01-06
# 3      1332000          0  1332000   888000   444000.0 2014-01-06
# 4      3705000          0  3705000  2470000  1235000.0 2014-01-06

# %%
 for col in df.describe(include = 'object').columns:
    print(col)
    print(df[col].unique())
    print('-'*50)
# Out:
# Segment
# ['Government' 'Midmarket' 'Channel Partners' 'Enterprise' 'Small Business']
# --------------------------------------------------
# Country
# ['Canada' 'Germany' 'France' 'Mexico' 'United States of America']
# --------------------------------------------------

# %%
df["Profit"].fillna(df['Profit'].mean(),inplace=True)

# %%
sample = df['Profit']

# %%
outliers =[]
def detect_outliers_iqr(data):
    data = sorted(data)
    q1 = np.percentile(data,25)
    q3 = np.percentile(data,75)
    IQR = q3 - q1
    lwr_bound = q1 - (1.5*IQR)
    upr_bound = q3 + (1.5*IQR)
    for i in data:
        if (i<lwr_bound or i>upr_bound):
            outliers.append(i)
    return outliers
sample_outliers = detect_outliers_iqr(sample)
print("Outliers from IQR method",sample_outliers)
# Out:
# Outliers from IQR method [6324900.0, 6324900.0, 6396000.0, 6396000.0, 6696000.0, 6762000.0, 7064200.0, 7423650.0, 7423650.0, 7526250.0, 7603200.0, 7645950.0, 7651200.0, 7679800.0, 7679800.0, 7683400.0, 7795200.0, 7880200.0, 7906275.0, 7965500.0, 7966300.0, 8066250.0, 8161275.0, 8430400.0, 8430400.0, 8444400.0, 8444400.0, 8725050.0, 8745750.0, 8903000.0, 8903000.0, 9054000.0, 9054000.0, 9132750.0, 9746100.0, 9787500.0, 9981450.0, 10005000.0, 10037625.0, 10074000.0, 10285000.0, 10322400.0, 10322400.0, 10466500.0, 10691250.0, 10755000.0, 10814700.0, 10838175.0, 11088400.0, 11534550.0, 11585100.0, 11660400.0, 11712400.0, 11712400.0, 11740600.0, 12084050.0, 12084050.0, 12115350.0, 12320000.0, 12721500.0, 13053900.0, 13305200.0, 13512800.0, 13617000.0, 13617000.0, 13653500.0, 13743000.0, 14139450.0, 14174000.0, 14286150.0, 14324400.0, 14324400.0, 14493200.0, 15438500.0, 15525000.0, 16102000.0, 16545200.0, 16545200.0, 18640750.0, 18640750.0, 18837800.0, 23671600.0, 23671600.0, 23879100.0, 2
# ...

# %%
median = np.median(sample)
c=np.where(np.isin(sample,sample_outliers),median,sample)
print("Sample",sample)
print("New Array",c)
# Out:
# Sample 0      1618500.0
# 1      1321000.0
# 2      1089000.0
# 3       444000.0
# 4      1235000.0
#          ...
# 695    1237500.0
# 696     273000.0
# 697     129960.0
# 698      68685.0
# 699    1300320.0
# Name: Profit, Length: 700, dtype: float64
# New Array [1618500.        1321000.        1089000.         444000.
#  1235000.        1250730.         460500.        2266200.
#  1899000.        1390500.        1235000.        1332750.
#  4790000.         429200.         172500.         307500.
#   292000.         487000.        2266200.        1250730.
#   330300.         176600.         274500.        3940000.
#  1236000.         228600.        1250730.         820800.
#  1076000.        1817000.        1250730.         298600.
#   902000.        1944900.        1250730.        1390500.
#  1410500.         172500.        1250730.        2554200.
#  1089000.         444000.        1250730.        1250730.
#  1817000.        1250730.        1757700.        2109750.
# ...

# %%
df['Profit'] = c

# %%
df.head()
# Out:
#       Segment  Country  Units Sold  Manufacturing Price  Sale Price  \
# 0  Government   Canada      161850                  300        2000
# 1  Government  Germany      132100                  300        2000
# 2   Midmarket   France      217800                  300        1500
# 3   Midmarket  Germany       88800                  300        1500
# 4   Midmarket   Mexico      247000                  300        1500
#
#    Gross Sales  Discounts    Sales     COGS     Profit       Date
# 0      3237000          0  3237000  1618500  1618500.0 2014-01-01
# 1      2642000          0  2642000  1321000  1321000.0 2014-01-01
# 2      3267000          0  3267000  2178000  1089000.0 2014-01-06
# 3      1332000          0  1332000   888000   444000.0 2014-01-06
# 4      3705000          0  3705000  2470000  1235000.0 2014-01-06

# %% [markdown]
# ## STEP 3 PLOTTING
#
#
# *  **HISTOGRAM**
# *  **BOXPLOT**

# %%
plt.hist(df['Profit'], bins=10, color='blue', edgecolor='black')
plt.title('Histogram of Profit')
plt.xlabel('Profit')
plt.ylabel('Sales')
plt.show()

# %%
df['Profit'].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
sample = df['Profit']

# %%
tenth_percentile = np.percentile(sample,10)
nintieth_percentile = np.percentile(sample,90)

b = np.where(sample<tenth_percentile,tenth_percentile,sample)
b = np.where(b>nintieth_percentile,nintieth_percentile,b)

#print("Sample",sample)
print("New Array",b)
# Out:
# New Array [1618500.        1321000.        1089000.         444000.
#  1235000.        1250730.         460500.        2266200.
#  1899000.        1390500.        1235000.        1332750.
#  2774101.0266876  429200.         204815.         307500.
#   292000.         487000.        2266200.        1250730.
#   330300.         204815.         274500.        2774101.0266876
#  1236000.         228600.        1250730.         820800.
#  1076000.        1817000.        1250730.         298600.
#   902000.        1944900.        1250730.        1390500.
#  1410500.         204815.        1250730.        2554200.
#  1089000.         444000.        1250730.        1250730.
#  1817000.        1250730.        1757700.        2109750.
#  1899000.         337200.        1926900.         228600.
#   307500.         761385.        1113560.         204815.
#   204815.         255918.        1649904.        1250730.
#   488097.        1283160.         204815.        2371848.
# ...

# %%
df['Profit'] = b

# %%
df['Profit'].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df['Profit'].plot(kind = 'kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### FEATURES AND THEIR RELATIONSHIP
#
# *  **SCATTER PLOT**
# *  **HEATMAP**

# %%
plt.figure(figsize = (10, 6))
plt.scatter(df['Sales'],df['COGS'],marker = 's',color = 'r')
plt.xlabel('Sales')
plt.ylabel('COGS')
plt.title('Cost of goods per sales')
plt.show()

# %%
df.head()
# Out:
#       Segment  Country  Units Sold  Manufacturing Price  Sale Price  \
# 0  Government   Canada      161850                  300        2000
# 1  Government  Germany      132100                  300        2000
# 2   Midmarket   France      217800                  300        1500
# 3   Midmarket  Germany       88800                  300        1500
# 4   Midmarket   Mexico      247000                  300        1500
#
#    Gross Sales  Discounts    Sales     COGS     Profit       Date
# 0      3237000          0  3237000  1618500  1618500.0 2014-01-01
# 1      2642000          0  2642000  1321000  1321000.0 2014-01-01
# 2      3267000          0  3267000  2178000  1089000.0 2014-01-06
# 3      1332000          0  1332000   888000   444000.0 2014-01-06
# 4      3705000          0  3705000  2470000  1235000.0 2014-01-06

# %%
df = df.head(100)
plt.figure(figsize=(10, 6))
plt.title('Rise of Profits per Sales', fontsize=30)
plt.plot(df['Sales'].index, df['Profit'], label='Sales')
plt.legend(fontsize=20)
plt.xlabel('Date')  # Adding x-label
plt.ylabel('Profits')  # Adding y-label
plt.show()

# %%
sns.violinplot(df['Profit'])
# Out:
# <AxesSubplot:xlabel='Profit'>

# %%
df.sample()
# Out:
#        Segment Country  Units Sold  Manufacturing Price  Sale Price  \
# 32  Enterprise  France      180400                12000       12500
#
#     Gross Sales  Discounts     Sales      COGS    Profit       Date
# 32     22550000          0  22550000  21648000  902000.0 2014-01-02

# %%
df2=df[['Units Sold','Manufacturing Price','Sale Price','Gross Sales','COGS','Profit','Date']].dropna().corr()

# %%
df2
# Out:
#                      Units Sold  Manufacturing Price  Sale Price  Gross Sales  \
# Units Sold             1.000000            -0.002888   -0.048450     0.267756
# Manufacturing Price   -0.002888             1.000000    0.069332     0.075516
# Sale Price            -0.048450             0.069332    1.000000     0.862985
# Gross Sales            0.267756             0.075516    0.862985     1.000000
# COGS                   0.272259             0.083159    0.849721     0.994256
# Profit                 0.454661             0.074329    0.273279     0.248884
#
#                          COGS    Profit
# Units Sold           0.272259  0.454661
# Manufacturing Price  0.083159  0.074329
# Sale Price           0.849721  0.273279
# Gross Sales          0.994256  0.248884
# COGS                 1.000000  0.231194
# Profit               0.231194  1.000000

# %%
#subset_df = df2.head(200)
sns.heatmap(df2,annot=True)
# Out:
# <AxesSubplot:>
